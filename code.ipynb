# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
# eu 20170314
data = pd.read_csv("./data/20170314_charge_eu.csv")
data
# Out:
#          Unnamed: 0  ﻿user_no standard_country_code  charge_status  charge_no  \
# 0                 0  42000371                    PL             30    3002929
# 1                 1  42000543                    A1             30    3002980
# 2                 2  42000546                                   30    3002983
# 3                 3  42000663                                   30    3003038
# 4                 4  42000666                                   30    3003041
# 5                 5  42000676                                   30    3003044
# 6                 6  42000770                                   30    3003099
# 7                 7  42000777                                   30    3003102
# 8                 8  42000780                                   30    3003105
# 9                 9  42000792                                   30    3003108
# 10               10  42000984                                   30    3003208
# ...

# %%
data2 = pd.read_csv("./data/20170314_charge_na.csv")
data2
# Out:
#         Unnamed: 0  ﻿user_no standard_country_code  charge_status  charge_no  \
# 0                0  42000199                                   30  300001666
# 1                1  42000205                                   30  300001669
# 2                2  42000207                                   30  300001672
# 3                3  42000458                                   30  300001698
# 4                4  42000472                    A1             30  300001701
# 5                5  42000521                                   30  300001704
# 6                6  42000622                                   30  300001714
# 7                7  42000648                                   30  300001717
# 8                8  42000659                                   30  300001720
# 9                9  42000723                                   30  300001739
# 10              10  42000807                    A1             30  300001762
# ...

# %%
data3 = pd.read_csv("./data/20170314_purchase_na.csv")
data3
# Out:
#          Unnamed: 0  ﻿purchase_no   user_no service_code    product_key  \
# 0                 0            41  42000720       SVR014           5324
# 1                 1            45  42000720       SVR015           7417
# 2                 2            62  42000904       SVR015           1653
# 3                 3            68  42001001       SVR014           5317
# 4                 4            69  42000807       SVR007  K_C9_00022423
# 5                 5            71  42000807       SVR015          14179
# 6                 6            78  42000807       SVR002        2437_70
# 7                 7            89  42000720       SVR014           5324
# 8                 8           100  42000807       SVR002       3302_100
# 9                 9           110  42000720       SVR002         356_80
# 10               10           123  42000720       SVR002        2440_60
# 11               11           133  42000720       SVR002      3287_2900
# ...
